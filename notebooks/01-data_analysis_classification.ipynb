# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import joblib
import warnings

from resources.context import Context as c
from resources.featureengineering import FeatureEngineering
from resources.plotcreator import PlotCreator

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # Data Load

# %%
df0 = pd.read_csv(c().data_raw_fld() / 'case_1_data.csv')

# %% [markdown]
# # 1.0. Data Description

# %% [markdown]
# ## 1.1. Dict

# %%
pd.read_csv(c().data_proc_fld() / 'case_1_dict.csv')
# Out:
#                             attribute  \
# 0                         cod_anuncio
# 1                         cod_cliente
# 2                     cod_tipo_pessoa
# 3                          prioridade
# 4                               leads
# 5                               views
# 6                    cliques_telefone
# 7                   cod_marca_veiculo
# 8                  cod_modelo_veiculo
# 9                  cod_versao_veiculo
# 10                         ano_modelo
# 11                           cep_2dig
# 12                          uf_cidade
# 13                        vlr_anuncio
# 14                          qtd_fotos
# 15                         km_veiculo
# 16                        vlr_mercado
# 17                     flg_unico_dono
# 18                     flg_licenciado
# 19                      flg_ipva_pago
# 20  flg_todas_revisoes_concessionaria
# 21  flg_todas_revisoes_agenda_veiculo
# 22               flg_garantia_fabrica
# 23                       flg_blindado
# 24                   flg_aceita_troca
# 25                   flg_adaptado_pcd
# 26                        combustivel
# 27                             cambio
# 28                             portas
# 29                             alarme
# 30                             airbag
# 31                           arquente
# 32                         bancocouro
# 33                           arcondic
# 34                                abs
# 35                         desembtras
# 36                         travaeletr
# 37                        vidroseletr
# 38                          rodasliga
# 39                        sensorchuva
# 40                     sensorestacion
#
#                                           description
# 0                                   código do anúncio
# 1                                código do anunciante
# 2                      tipo de anunciante: PF=1, PJ=2
# 3    prioridade do anúncio (1=alta, 2-média, 3-baixa)
# 4                         tota de propostas recebidas
# 5              quantidade de visualizações no anúncio
# 6         quantidade de cliques no telefone anunciado
# 7                          código da marca do veículo
# 8                            código do modelo veículo
# 9                         código da versão do veículo
# 10                              ano-modelo do veículo
# 11        dois primeiros dígitos do cep do anunciante
# 12                          UF e cidade do anunciante
# 13                        valor do veículo no anúncio
# 14                     quantidade de fotos no anúncio
# 15                            Kilometragem do veículo
# 16            valor de referência do veículo na praça
# 17                            indicador de único dono
# 18                  indicador de licenciamento em dia
# 19                           indicador de IPVA em dia
# 20  indicador realização de todas as revisões na c...
# 21  indicador realização de todas as revisões prev...
# 22        indicador de veículo em garantia de fábrica
# 23                             indicador de blindagem
# 24         indicador de que o anunciante aceita troca
# 25  indicador de veículo adaptado para pessoa com ...
# 26                       especificação de combustível
# 27                            especificação de câmbio
# 28                                   número de portas
# 29                                 presença de alarme
# 30                                 presença de airbag
# 31                              presença de ar quente
# 32                         presença de banco de couro
# 33                        presença de ar condicionado
# 34                              presença de freio abs
# 35                  presença de desembaçador traseiro
# 36                       presença de travas elétricas
# 37                       presença de vidros elétricos
# 38                     presença de rodas de liga-leve
# 39                        presença de sensor de chuva
# 40               presença de sensor de estacionamento

# %% [markdown]
# ## 1.2. Shape

# %%
df0.shape
# Out:
# (48665, 41)

# %% [markdown]
# ## 1.3. Dtypes

# %%
df0.dtypes # no big mistake located, but some dtypes will be revised after data analysis
# Out:
# cod_anuncio                            int64
# cod_cliente                            int64
# cod_tipo_pessoa                        int64
# prioridade                             int64
# leads                                  int64
# views                                  int64
# cliques_telefone*                      int64
# cod_marca_veiculo                      int64
# cod_modelo_veiculo                     int64
# cod_versao_veiculo                     int64
# ano_modelo                             int64
# cep_2dig                               int64
# uf_cidade                             object
# vlr_anuncio                          float64
# qtd_fotos                              int64
# km_veiculo                             int64
# vlr_mercado                          float64
# flg_unico_dono                         int64
# flg_licenciado                         int64
# flg_ipva_pago                        float64
# flg_todas_revisoes_concessionaria    float64
# flg_todas_revisoes_agenda_veiculo      int64
# flg_garantia_fabrica                 float64
# flg_blindado                           int64
# flg_aceita_troca                       int64
# flg_adaptado_pcd                     float64
# combustivel                           object
# cambio                                object
# portas                               float64
# alarme                                object
# airbag                                object
# arquente                              object
# bancocouro                            object
# arcondic                              object
# abs                                   object
# desembtras                            object
# travaeletr                            object
# vidroseletr                           object
# rodasliga                             object
# sensorchuva                           object
# sensorestacion                        object
# dtype: object

# %% [markdown]
# ## 1.4. NAs

# %%
df0.isna().sum() # will be corrected after data analysis
# Out:
# cod_anuncio                             0
# cod_cliente                             0
# cod_tipo_pessoa                         0
# prioridade                              0
# leads                                   0
# views                                   0
# cliques_telefone*                       0
# cod_marca_veiculo                       0
# cod_modelo_veiculo                      0
# cod_versao_veiculo                      0
# ano_modelo                              0
# cep_2dig                                0
# uf_cidade                               0
# vlr_anuncio                             0
# qtd_fotos                               0
# km_veiculo                              0
# vlr_mercado                          6217
# flg_unico_dono                          0
# flg_licenciado                          0
# flg_ipva_pago                         312
# flg_todas_revisoes_concessionaria     312
# flg_todas_revisoes_agenda_veiculo       0
# flg_garantia_fabrica                  312
# flg_blindado                            0
# flg_aceita_troca                        0
# flg_adaptado_pcd                      312
# combustivel                             1
# cambio                                  1
# portas                                  1
# alarme                                  1
# airbag                                  8
# arquente                                1
# bancocouro                              1
# arcondic                                1
# abs                                     1
# desembtras                              1
# travaeletr                              1
# vidroseletr                             1
# rodasliga                               1
# sensorchuva                             1
# sensorestacion                          1
# dtype: int64

# %% [markdown]
# ## 1.5. Statistical Description

# %%
data_analysis = PlotCreator(df=df0)
data_analysis.statistical_description(saving_figloc=(c().reports_fld() / 'classification/statistical_description.png'))
# Out:
# [0807/071711.746983:ERROR:sandbox_linux.cc(378)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0807/071711.867728:INFO:headless_shell.cc(653)] Written to file /tmp/tmpxr26k3fb/temp.png.
#                            attributes      mean    median         std   min  \
# 0                         cod_anuncio  98293.33  98030.00    56500.69  2.00
# 1                         cod_cliente   8804.72   6778.00     7954.61  1.00
# 2                     cod_tipo_pessoa      1.85      2.00        0.36  1.00
# 3                          prioridade      2.60      3.00        0.77  1.00
# 4                               leads      4.42      1.00       11.96  0.00
# 5                               views    446.33    196.00     1105.24  0.00
# 6                   cliques_telefone*      7.47      4.00       11.45  0.00
# 7                   cod_marca_veiculo     19.28      5.00       37.63 -1.00
# 8                  cod_modelo_veiculo   2063.22   2487.00     1112.00 -1.00
# 9                  cod_versao_veiculo 342632.76 344132.00    13247.79 -1.00
# 10                         ano_modelo   2013.11   2014.00       13.77 -1.00
# 11                           cep_2dig     37.85     22.00       33.44  0.00
# 12                        vlr_anuncio 109279.54  41000.00  2866351.70  0.00
# 13                          qtd_fotos      6.63      8.00        2.17  0.00
# 14                         km_veiculo 379000.66  57000.00 20127194.15  0.00
# 15                        vlr_mercado  52757.15       NaN    41608.59   NaN
# 16                     flg_unico_dono      0.21      0.00        0.41  0.00
# 17                     flg_licenciado      0.30      0.00        0.46  0.00
# 18                      flg_ipva_pago      0.40       NaN        0.49  0.00
# 19  flg_todas_revisoes_concessionaria      0.15       NaN        0.36  0.00
# 20  flg_todas_revisoes_agenda_veiculo      0.07      0.00        0.25  0.00
# 21               flg_garantia_fabrica      0.09       NaN        0.28  0.00
# 22                       flg_blindado      0.02      0.00        0.14  0.00
# 23                   flg_aceita_troca      0.09      0.00        0.28  0.00
# 24                   flg_adaptado_pcd      0.00       NaN        0.02  0.00
# 25                             portas      3.73       NaN        0.82   NaN
#
#              max         range    skew  kurtosis
# 0      195939.00     195937.00   -0.00     -1.20
# 1       38733.00      38732.00    1.91      3.42
# 2           2.00          1.00   -1.94      1.76
# 3           3.00          2.00   -1.50      0.38
# 4         364.00        364.00    9.78    168.52
# 5       93608.00      93608.00   31.92   2135.42
# 6         457.00        457.00    7.99    143.94
# 7         320.00        321.00    4.89     25.32
# 8        3695.00       3696.00   -0.03     -1.78
# 9      347841.00     347842.00  -20.72    491.92
# 10       2019.00       2020.00 -128.85  18829.76
# 11         99.00         99.00    0.52     -1.41
# 12  405000000.00  405000000.00   86.78   9841.10
# 13         20.00         20.00   -1.68      2.38
# 14 2147483647.00 2147483647.00   78.19   6838.62
# 15           NaN    1104922.80    4.89     48.49
# 16          1.00          1.00    1.45      0.09
# 17          1.00          1.00    0.85     -1.27
# 18          1.00          1.00    0.40     -1.84
# 19          1.00          1.00    1.95      1.79
# 20          1.00          1.00    3.47     10.06
# 21          1.00          1.00    2.96      6.75
# 22          1.00          1.00    6.71     43.02
# 23          1.00          1.00    2.96      6.79
# 24          1.00          1.00   49.14   2412.90
# 25           NaN          4.00   -3.19      9.83

# %% [markdown]
# ## 1.6. Analyzing Distortions

# %% [markdown]
# ### leads (need to be transformed in 0 or 1)

# %%
# transforming in 0 or 1 for classification models
df0['leads'] = df0['leads'].apply(lambda x: 0 if x == 0 else 1)

# %% [markdown]
# ### ano_modelo (It's strange to having -1 values, need to be corrected.)

# %%
df0['ano_modelo'].sort_values(ascending=True).unique()
# Out:
# array([  -1, 1951, 1952, 1958, 1959, 1961, 1962, 1963, 1964, 1965, 1966,
#        1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977,
#        1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988,
#        1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
#        2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019])

# %% [markdown]
# ### vlr_anuncio (No problem detected, values can be bigs or lower in real life)

# %%
df0['vlr_anuncio'].sort_values(ascending=False).head(60)
# Out:
# 28985   405000000.00
# 17564   218500000.00
# 20971   195000000.00
# 15054   158000000.00
# 35988   122000000.00
# 45956   122000000.00
# 30300   113900000.00
# 36590   108000000.00
# 16924    90899000.00
# 47079    87000000.00
# 22959    82500000.00
# 41307    81500000.00
# 46372    81000000.00
# 45060    79000000.00
# 44185    74900000.00
# 47115    54000000.00
# 26527    53000000.00
# 16931    50900000.00
# 18623    49900000.00
# 22250    46000000.00
# 19207    45500000.00
# 36939    43000000.00
# 4594     42990000.00
# 33525    33000000.00
# 39756    29200000.00
# 34541    28000000.00
# 21986    27000000.00
# 22120    25000000.00
# 45731    18000000.00
# 940       8888888.00
# 29754     7100000.00
# 47085     3299000.00
# 35977     2860000.00
# 44616     2149000.00
# 41897     2149000.00
# 34163     1990000.00
# 45515     1990000.00
# 42544     1799000.00
# 41896     1590000.00
# 47943     1300000.00
# 2144      1290000.00
# 39844     1275000.00
# 43176     1250000.00
# 99        1235000.00
# 725       1230000.00
# 43996     1220000.00
# 11582     1200000.00
# 17768     1166900.00
# 16957     1150000.00
# 6305      1074800.00
# 32487     1050000.00
# 42996     1050000.00
# 42537     1000000.00
# 34549      990000.00
# 2556       980000.00
# 5321       970000.00
# 28070      950000.00
# 13779      940000.00
# 37850      850000.00
# 44888      835800.00
# Name: vlr_anuncio, dtype: float64

# %%
data_analysis.outlier_detector_boxplot(x='vlr_anuncio', saving_figloc=(c().reports_fld() / 'vlr_anuncio_boxplot.jpg'))

# %% [markdown]
# ### km_veiculo (No problem detected, values can be bigs or lower in real life)

# %%
df0['km_veiculo'].sort_values(ascending=False).head(60)
# Out:
# 1473     2147483647
# 45076    2147483647
# 17649    1111111111
# 30366    1111111111
# 18267    1111111111
# 15409    1111111111
# 20907    1111111111
# 18270    1111111111
# 21120    1000000000
# 1371      999999999
# 93        999999999
# 30730     117800000
# 33932     111111111
# 11824     111111111
# 37251     101010101
# 4396       99999999
# 6          99999999
# 112        99999999
# 39100      34747878
# 39105      34747878
# 8155       34747878
# 8153       34747878
# 8152       34747878
# 8151       34747878
# 8150       34747878
# 8149       34747878
# 43084      23000000
# 14089      11111111
# 46511      11111111
# 13872      11111111
# 31706      11111111
# 387        10000000
# 6353       10000000
# 14511       9999999
# 39189       9999999
# 2852        6950000
# 24723       6666666
# 643         6200000
# 7711        1999622
# 39376       1320000
# 39469       1234567
# 9274        1171955
# 23005       1111111
# 38842       1111111
# 6471        1111111
# 38844       1111111
# 38854       1111111
# 7443        1111111
# 40156       1111111
# 30446       1111111
# 30459       1111111
# 23966       1111111
# 14165       1111111
# 29989       1111111
# 33825       1111111
# 20603       1111111
# 43626       1111111
# 27458       1111111
# 12631       1111111
# 23968       1111111
# Name: km_veiculo, dtype: int64

# %%
data_analysis.outlier_detector_boxplot(x='km_veiculo', saving_figloc=(c().reports_fld() / 'km_veiculo_boxplot.jpg'))

# %% [markdown]
# ### vlr_mercado (No problem detected, values can be bigs or lower in real life)

# %%
df0['vlr_mercado'].sort_values(ascending=False).head(60)
# Out:
# 99      1111215.64
# 28070    921239.19
# 37850    852017.64
# 46617    692232.62
# 8706     686493.28
# 26840    682807.84
# 41540    641419.78
# 9643     637500.30
# 27801    629791.31
# 44310    623206.01
# 18527    595709.16
# 41498    594854.55
# 38218    577738.63
# 26908    517975.97
# 26928    516651.25
# 31301    516505.68
# 47460    516156.93
# 39613    513796.25
# 44613    512349.52
# 40389    508006.12
# 42839    506636.97
# 42824    502580.24
# 3061     502005.99
# 20967    501079.39
# 10824    499700.58
# 45505    499683.49
# 10564    490091.68
# 32582    484606.66
# 10017    484606.66
# 35120    481766.23
# 23326    481660.53
# 3720     477414.36
# 6958     473665.43
# 38293    472119.70
# 38642    469872.48
# 37380    469382.59
# 22020    467995.69
# 10117    464097.91
# 41453    461309.06
# 15841    461034.37
# 28793    448629.64
# 48354    447661.18
# 44938    446918.88
# 40271    443799.03
# 48547    439176.32
# 2813     433270.38
# 28888    431212.18
# 33994    430963.18
# 10699    430154.44
# 21534    428313.04
# 23527    428313.04
# 9001     427157.47
# 36959    426844.49
# 34496    425622.55
# 14212    425499.74
# 28204    425192.57
# 21002    424818.98
# 30478    424818.98
# 35254    422866.72
# 44173    421036.41
# Name: vlr_mercado, dtype: float64

# %%
data_analysis.outlier_detector_boxplot(x='vlr_mercado', saving_figloc=(c().reports_fld() / 'vlr_mercado_boxplot.jpg'))

# %% [markdown]
# ### portas (No problem detected, values NA will be treated in next phases)

# %%
df0['portas'].sort_values(ascending=True).unique()
# Out:
# array([ 0.,  2.,  3.,  4., nan])

# %%
df0['portas'].isna().sum()
# Out:
# 1

# %% [markdown]
# # 2.0. Feature Engineering

# %%
df1 = df0.copy()

# %% [markdown]
# ## 2.1. Cleaning Dirty

# %%
dirty = ['cod_marca_veiculo', 'cod_modelo_veiculo', 'cod_versao_veiculo', 'ano_modelo']

for d in dirty:
    df1 = df1[df1[d] >= 0]

df1.shape # just two rows was deleted, then I will keep going!
# Out:
# (48663, 41)

# %% [markdown]
# ## 2.2. Filtering NA (Just 13,37% of rows are going to be lost, then I will just filter all NA to guarantee the integrity of data)

# %%
(1 - (df1.dropna().shape[0]/df1.shape[0]))*100
# Out:
# 13.369500441814107

# %%
df1.dropna().shape[0]
# Out:
# 42157

# %%
df1.shape[0]
# Out:
# 48663

# %%
df1.dropna(inplace=True)

# %% [markdown]
# ## 2.3. Separating Columns

# %%
cod_gran = 'cod_anuncio'

res_var = 'leads'

cat_list  = ['flg_unico_dono', 'flg_licenciado', 'flg_ipva_pago', 
       'flg_todas_revisoes_concessionaria',
       'flg_todas_revisoes_agenda_veiculo', 'flg_garantia_fabrica', 'flg_blindado', 
       'flg_aceita_troca', 'flg_adaptado_pcd', 'prioridade', 
       'combustivel', 'cambio', 'portas', 'alarme',
       'airbag', 'arquente', 'bancocouro','arcondic', 'abs', 'desembtras', 
       'travaeletr', 'vidroseletr', 'rodasliga', 'sensorchuva', 'sensorestacion',
       'cod_tipo_pessoa']
       
cont_list = ['views', 'cliques_telefone*', 'vlr_anuncio', 
       'qtd_fotos', 'km_veiculo', 'vlr_mercado']

special_cases_list = ['cod_cliente', 'cep_2dig', 'uf_cidade',
                     'cod_marca_veiculo', 'cod_modelo_veiculo', 'cod_versao_veiculo',
                     'ano_modelo']

# %% [markdown]
# ## 2.4. Changing Dtypes

# %%
df1 = df1[df1[cod_gran] >= 0]
df1[cod_gran] = df1[cod_gran].astype(str)
df1[special_cases_list] = df1[special_cases_list].astype(str)
df1[cat_list] = df1[cat_list].astype(str)
df1[cont_list] = df1[cont_list].astype(float)

# %% [markdown]
# ## 2.5. Derivating New Variables

# %%
feat_eng = FeatureEngineering(df=df1)
df1['uf'] = feat_eng.uf()
df1['decade'] = feat_eng.decade()
df1['ipva_dono'] = feat_eng.ipva_dono()
df1['sensors'] = feat_eng.sensors()
df1['eletr_car'] = feat_eng.eletr_car()

# %%
cat_list.append('uf')
cat_list.append('decade')
cat_list.append('ipva_dono')
cat_list.append('sensors')
cat_list.append('eletr_car')

# %% [markdown]
# # 3.0. Data Analysis

# %% [markdown]
# ## 3.1. Continuous Variables

# %%
dataanalysis = PlotCreator(df=df1)

for expl_var in cont_list:
    saving_figloc=(c().reports_fld() / f'classification/{expl_var}_cont_eda.jpg')
    dataanalysis.plot_cat_analy(df=df1, expl_var='leads', res_var=expl_var, categorical=True, saving_figloc=saving_figloc)

# %% [markdown]
# ## 3.2. Categorical Variables

# %%
cat_var_analy = PlotCreator(df=df1)

for expl_var in cat_list:
    saving_figloc=(c().reports_fld() / f'classification/{expl_var}_cat_eda.jpg')
    cat_var_analy.plot_cat_analy(res_var='leads', expl_var=expl_var, saving_figloc=saving_figloc)

# %% [markdown]
# ## 3.3. Special Cases

# %% [markdown]
# ### Num of Uniques in Special Cases

# %%
for s in special_cases_list:
    print(f'Num of unique in {s}: {len(df1[s].unique())}')
# Out:
# Num of unique in cod_cliente: 14114
# Num of unique in cep_2dig: 97
# Num of unique in uf_cidade: 850
# Num of unique in cod_marca_veiculo: 44
# Num of unique in cod_modelo_veiculo: 432
# Num of unique in cod_versao_veiculo: 2894
# Num of unique in ano_modelo: 45

# %% [markdown]
# ### Dropping Extremaly Cases

# %%
# dropping these vars because they are IDs who can't be groupped
# even if this can be put in a model, can't be analyzed with security
# then, for control and explainability, I prefer to drop these columns
# the column "uf_cidade" and "ano_modelo" was treated before and derivated some information from them
drop_vars = ['cod_cliente', 'cod_versao_veiculo', 'cod_modelo_veiculo', 'uf_cidade',
            'cep_2dig', 'ano_modelo']

# %%
df1.drop(drop_vars, axis=1, inplace=True)

# %% [markdown]
# ### Analyzing Special Cases

# %%
cat_svar_analy = PlotCreator(df=df1.sort_values('cod_marca_veiculo'))
saving_figloc=(c().reports_fld() / f'classification/{expl_var}_cv_eda.jpg')
cat_svar_analy.plot_cat_analy(res_var='leads', expl_var='cod_marca_veiculo', saving_figloc=saving_figloc)

# %% [markdown]
# ## 3.4. Keeping Cols Based in EDA

# %%
# these are the best columns based in EDA Analysis
keep_cols = ['views', 'cliques_telefone', 'prioridade', 'flg_aceita_troca',
            'flg_licenciado', 'flg_blindado', 'cod_tipo_pessoa']
df_prepare = df1[keep_cols]

# %% [markdown]
# # Data Save

# %%
joblib.dump(df_prepare, open((c().data_proc_fld() / '01_df_prepared_class.pkl'), 'wb'))
